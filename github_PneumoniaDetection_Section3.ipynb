# %% [markdown]
# <a href="https://colab.research.google.com/github/rachitj27/pnemonia-detection/blob/main/github_PneumoniaDetection_Section3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Run this to download data and prepare our environment! { display-mode: "form" }
# %tensorflow_version 1.x
import random

import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, confusion_matrix

import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, GlobalAveragePooling2D
from keras.regularizers import l2
from keras.wrappers.scikit_learn import KerasClassifier
import tensorflow.keras.optimizers as optimizers
from keras.callbacks import ModelCheckpoint

from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121

from imgaug import augmenters
def augment(data, augmenter):
  if len(data.shape) == 3:
    return augmenter.augment_image(data)
  if len(data.shape) == 4:
    return augmenter.augment_images(data)

def rotate(data, rotate):
  fun = augmenters.Affine(rotate = rotate)
  return augment(data, fun)

def shear(data, shear):
  fun = augmenters.Affine(shear = shear)
  return augment(data, fun)

def scale(data, scale):
  fun = augmenters.Affine(scale = scale)
  return augment(data, fun)

def flip_left_right(data, prob):
  fun = augmenters.Fliplr(p = prob)
  return augment(data, fun)

def flip_up_down(data, prob):
  fun = augmenters.Flipud(p = prob)
  return augment(data, fun)

def remove_color(data, channel):
  new_data = data.copy()
  if len(data.shape) == 3:
    new_data[:,:,channel] = 0
    return new_data
  if len(data.shape) == 4:
    new_data[:,:,:,channel] = 0
    return new_data

class pkg:
  #### DOWNLOADING AND LOADING DATA
  def get_metadata(metadata_path, which_splits = ['train', 'test']):
    '''returns metadata dataframe which contains columns of:
       * index: index of data into numpy data
       * class: class of image
       * split: which dataset split is this a part of?
    '''
    metadata = pd.read_csv(metadata_path)
    keep_idx = metadata['split'].isin(which_splits)
    return metadata[keep_idx]

  def get_data_split(split_name, flatten, all_data, metadata, image_shape):
    '''
    returns images (data), labels from folder of format [image_folder]/[split_name]/[class_name]/
    flattens if flatten option is True
    '''
    sub_df = metadata[metadata['split'].isin([split_name])]
    index  = sub_df['index'].values
    labels = sub_df['class'].values
    data = all_data[index,:]
    if flatten:
      data = data.reshape([-1, np.product(image_shape)])
    return data, labels

  def get_train_data(flatten, all_data, metadata, image_shape):
    return get_data_split('train', flatten, all_data, metadata, image_shape)

  def get_test_data(flatten, all_data, metadata, image_shape):
    return get_data_split('test', flatten, all_data, metadata, image_shape)

  def get_field_data(flatten, all_data, metadata, image_shape):
    field_data, field_labels = get_data_split('field', flatten, all_data, metadata, image_shape)
    field_data[:,:,:,2] = field_data[:,:,:,0]
    field_data[:,:,:,1] = field_data[:,:,:,0]

    #make data messier
    rand = random.uniform(-1, 1)

    for i in range(len(field_data)):
      image = field_data[i]

      if abs(rand) < 0.5:
        image = rotate(image, rotate = rand * 40)
      elif abs(rand) < 0.8:
        image = shear(image, shear = rand*40)
      field_data[i] = image
    return field_data, field_labels

class helpers:
  #### PLOTTING
  def plot_one_image(data, labels = [], index = None, image_shape = [64,64,3]):
    '''
    if data is a single image, display that image

    if data is a 4d stack of images, display that image
    '''
    num_dims   = len(data.shape)
    num_labels = len(labels)

    # reshape data if necessary
    if num_dims == 1:
      data = data.reshape(target_shape)
    if num_dims == 2:
      data = data.reshape(np.vstack[-1, image_shape])
    num_dims   = len(data.shape)

    # check if single or multiple images
    if num_dims == 3:
      if num_labels > 1:
        print('Multiple labels does not make sense for single image.')
        return

      label = labels
      if num_labels == 0:
        label = ''
      image = data

    if num_dims == 4:
      image = data[index, :]
      label = labels[index]

    # plot image of interest
    print('Label: %s'%label)
    plt.imshow(image)
    plt.show()

  #### QUERYING AND COMBINING DATA
  def combine_data(data_list, labels_list):
    return np.concatenate(data_list, axis = 0), np.concatenate(labels_list, axis = 0)

  def plot_acc(history, ax = None, xlabel = 'Epoch #'):
    # i'm sorry for this function's code. i am so sorry.
    history = history.history
    history.update({'epoch':list(range(len(history['val_accuracy'])))})
    history = pd.DataFrame.from_dict(history)

    best_epoch = history.sort_values(by = 'val_accuracy', ascending = False).iloc[0]['epoch']

    if not ax:
      f, ax = plt.subplots(1,1)
    sns.lineplot(x = 'epoch', y = 'val_accuracy', data = history, label = 'Validation', ax = ax)
    sns.lineplot(x = 'epoch', y = 'accuracy', data = history, label = 'Training', ax = ax)
    ax.axhline(0.5, linestyle = '--',color='red', label = 'Chance')
    ax.axvline(x = best_epoch, linestyle = '--', color = 'green', label = 'Best Epoch')
    ax.legend(loc = 4)
    ax.set_ylim([0.4, 1])

    ax.set_xlabel(xlabel)
    ax.set_ylabel('Accuracy (Fraction)')

    plt.show()

class models:
  def DenseClassifier(hidden_layer_sizes, nn_params):
    model = Sequential()
    model.add(Flatten(input_shape = nn_params['input_shape']))
    model.add(Dropout(0.5))

    for ilayer in hidden_layer_sizes:
      model.add(Dense(ilayer, activation = 'relu'))
      model.add(Dropout(0.5))

    model.add(Dense(units = nn_params['output_neurons'], activation = nn_params['output_activation']))
    model.compile(loss=nn_params['loss'],
                  optimizer=keras.optimizers.SGD(learning_rate=1e-4, momentum=0.95),
                  metrics=['accuracy'])
    return model

  def CNNClassifier(num_hidden_layers, nn_params):
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=nn_params['input_shape'], padding = 'same', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    for i in range(num_hidden_layers-1):
        model.add(Conv2D(64, (3, 3), padding = 'same', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(units = 128, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(units = 64, activation = 'relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dropout(0.5))

    model.add(Dense(units = nn_params['output_neurons'], activation = nn_params['output_activation']))

    # initiate RMSprop optimizer
    opt = keras.optimizers.legacy.RMSprop(learning_rate=1e-5, decay=1e-6)

    # Let's train the model using RMSprop
    model.compile(loss=nn_params['loss'],
                  optimizer=opt,
                  metrics=['accuracy'])
    return model

  def TransferClassifier(name, nn_params, trainable = True):
    expert_dict = {'VGG16': VGG16,
                   'VGG19': VGG19,
                   'ResNet50':ResNet50,
                   'DenseNet121':DenseNet121}

    expert_conv = expert_dict[name](weights = 'imagenet',
                                              include_top = False,
                                              input_shape = nn_params['input_shape'])
    for layer in expert_conv.layers:
      layer.trainable = trainable

    expert_model = Sequential()
    expert_model.add(expert_conv)
    expert_model.add(GlobalAveragePooling2D())

    expert_model.add(Dense(128, activation = 'relu'))
    expert_model.add(Dropout(0.5))

    expert_model.add(Dense(64, activation = 'relu'))
    expert_model.add(Dropout(0.5))

    expert_model.add(Dense(nn_params['output_neurons'], activation = nn_params['output_activation']))

    expert_model.compile(loss = nn_params['loss'],
                  optimizer = keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
                  metrics=['accuracy'])

    return expert_model

### defining project variables
# file variables
metadata_url         = "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/metadata.csv"
image_data_url       = 'https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/image_data.npy'
image_data_path      = './image_data.npy'
metadata_path        = './metadata.csv'
image_shape          = (64, 64, 3)

# neural net parameters
nn_params = {}
nn_params['input_shape']       = image_shape
nn_params['output_neurons']    = 1
nn_params['loss']              = 'binary_crossentropy'
nn_params['output_activation'] = 'sigmoid'

###
# !wget -q --show-progress "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/metadata.csv"
# !wget -q --show-progress "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/image_data.npy"


### pre-loading all data of interest
_all_data = np.load('image_data.npy')
_metadata = pkg.get_metadata(metadata_path, ['train','test','field'])

### preparing definitions
# downloading and loading data
get_data_split = pkg.get_data_split
get_metadata    = lambda :                 pkg.get_metadata(metadata_path, ['train','test'])
get_train_data  = lambda flatten = False : pkg.get_train_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)
get_test_data   = lambda flatten = False : pkg.get_test_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)
get_field_data  = lambda flatten = False : pkg.get_field_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)

# plotting
plot_one_image = lambda data, labels = [], index = None: helpers.plot_one_image(data = data, labels = labels, index = index, image_shape = image_shape);
plot_acc       = lambda history: helpers.plot_acc(history)

# querying and combining data
combine_data           = helpers.combine_data;

# models with input parameters
DenseClassifier     = lambda hidden_layer_sizes: models.DenseClassifier(hidden_layer_sizes = hidden_layer_sizes, nn_params = nn_params);
CNNClassifier       = lambda num_hidden_layers: models.CNNClassifier(num_hidden_layers, nn_params = nn_params);
TransferClassifier  = lambda name: models.TransferClassifier(name = name, nn_params = nn_params);

monitor = ModelCheckpoint('./model.h5', monitor='val_accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
# Out:
# metadata.csv        100%[===================>]  39.56K  --.-KB/s    in 0s
# image_data.npy      100%[===================>] 131.25M   201MB/s    in 0.7s

# %%
train_data, train_labels = get_train_data()
test_data, test_labels   = get_test_data()

cnn = CNNClassifier(2)
cnn_history = cnn.fit(train_data, train_labels, epochs = 5, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])

### YOUR CODE HERE


### END CODE
# Out:
# Epoch 1/5
# 63/63 [==============================] - 11s 19ms/step - loss: 2.0147 - accuracy: 0.5120 - val_loss: 2.0004 - val_accuracy: 0.5600
# Epoch 2/5
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9912 - accuracy: 0.5580 - val_loss: 1.9773 - val_accuracy: 0.6400
# Epoch 3/5
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9637 - accuracy: 0.6030 - val_loss: 1.9459 - val_accuracy: 0.7500
# Epoch 4/5
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9321 - accuracy: 0.6455 - val_loss: 1.9210 - val_accuracy: 0.7350
# Epoch 5/5
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9057 - accuracy: 0.6795 - val_loss: 1.8926 - val_accuracy: 0.8150

# %%
transfer = TransferClassifier(name = 'VGG19')
transfer_history = transfer.fit(train_data, train_labels, epochs = 5, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step
# Epoch 1/5
# 63/63 [==============================] - 11s 93ms/step - loss: 0.6978 - accuracy: 0.5930 - val_loss: 0.5354 - val_accuracy: 0.8300
# Epoch 2/5
# 63/63 [==============================] - 4s 70ms/step - loss: 0.4447 - accuracy: 0.7965 - val_loss: 0.3592 - val_accuracy: 0.8625
# Epoch 3/5
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2684 - accuracy: 0.9090 - val_loss: 0.4313 - val_accuracy: 0.8200
# Epoch 4/5
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2036 - accuracy: 0.9325 - val_loss: 0.8195 - val_accuracy: 0.6850
# Epoch 5/5
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1588 - accuracy: 0.9480 - val_loss: 1.2186 - val_accuracy: 0.6175

# %%
plot_acc(cnn_history)
cnn.evaluate(test_data, test_labels)
# Out:
# 13/13 [==============================] - 0s 5ms/step - loss: 1.8859 - accuracy: 0.7900
# [1.8858680725097656, 0.7900000214576721]

# %%
field_data, field_labels = get_field_data()

# %%
field_pred = cnn.predict(field_data) > 0.5
accuracy_score(field_pred, field_labels)
# Out:
# 13/13 [==============================] - 0s 6ms/step
# 0.715

# %%
field_pred = transfer.predict(field_data) > 0.5
accuracy_score(field_pred, field_labels)
# Out:
# 13/13 [==============================] - 0s 20ms/step
# 0.6225

# %%
acc = 0
for i in range (5):
  cnn = CNNClassifier(2)
  cnn_history = cnn.fit(train_data, train_labels, epochs = 5, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
  field_pred = cnn.predict(field_data) > 0.5
  acc = acc + (accuracy_score(field_pred, field_labels))

print(acc/5)


### END CODE
# Out:
# Epoch 1/5
# 63/63 [==============================] - 2s 20ms/step - loss: 2.0019 - accuracy: 0.5430 - val_loss: 1.9901 - val_accuracy: 0.7350
# Epoch 2/5
# 63/63 [==============================] - 1s 16ms/step - loss: 1.9755 - accuracy: 0.6105 - val_loss: 1.9621 - val_accuracy: 0.8175
# Epoch 3/5
# 63/63 [==============================] - 1s 16ms/step - loss: 1.9477 - accuracy: 0.6695 - val_loss: 1.9380 - val_accuracy: 0.7300
# Epoch 4/5
# 63/63 [==============================] - 1s 15ms/step - loss: 1.9153 - accuracy: 0.7115 - val_loss: 1.9085 - val_accuracy: 0.8075
# Epoch 5/5
# 63/63 [==============================] - 1s 10ms/step - loss: 1.8943 - accuracy: 0.7305 - val_loss: 1.8842 - val_accuracy: 0.7575
# 13/13 [==============================] - 0s 3ms/step
# Epoch 1/5
# 63/63 [==============================] - 2s 11ms/step - loss: 2.0088 - accuracy: 0.5305 - val_loss: 1.9951 - val_accuracy: 0.5725
# Epoch 2/5
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9834 - accuracy: 0.5775 - val_loss: 1.9670 - val_accuracy: 0.7575
# Epoch 3/5
# 63/63 [==============================] - 1s 10ms/step - loss: 1.9520 - accuracy: 0.6435 - val_loss: 1.9438 - val_accuracy: 0.7650
# Epoch 4/5
# 63/63 [==============================] - 1s 10ms/step - loss: 1.9265 - accuracy: 0.6550 - val_loss: 1.9124 - val_accuracy: 0.8100
# Epoch 5/5
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8944 - accuracy: 0.6975 - val_loss: 1.8840 - val_accuracy: 0.8125
# 13/13 [==============================] - 0s 3ms/step
# Epoch 1/5
# 63/63 [==============================] - 2s 12ms/step - loss: 2.0078 - accuracy: 0.5195 - val_loss: 1.9938 - val_accuracy: 0.5125
# Epoch 2/5
# 63/63 [==============================] - 0s 8ms/step - loss: 1.9835 - accuracy: 0.5595 - val_loss: 1.9712 - val_accuracy: 0.6125
# Epoch 3/5
# 63/63 [==============================] - 0s 8ms/step - loss: 1.9603 - accuracy: 0.6010 - val_loss: 1.9471 - val_accuracy: 0.6350
# Epoch 4/5
# 63/63 [==============================] - 0s 8ms/step - loss: 1.9351 - accuracy: 0.6555 - val_loss: 1.9227 - val_accuracy: 0.8075
# Epoch 5/5
# 63/63 [==============================] - 0s 8ms/step - loss: 1.9046 - accuracy: 0.6855 - val_loss: 1.8973 - val_accuracy: 0.8050
# 13/13 [==============================] - 0s 3ms/step
# Epoch 1/5
# 63/63 [==============================] - 2s 13ms/step - loss: 2.0221 - accuracy: 0.5565 - val_loss: 2.0099 - val_accuracy: 0.5275
# Epoch 2/5
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9908 - accuracy: 0.6120 - val_loss: 1.9747 - val_accuracy: 0.7400
# Epoch 3/5
# 63/63 [==============================] - 1s 11ms/step - loss: 1.9622 - accuracy: 0.6435 - val_loss: 1.9448 - val_accuracy: 0.8250
# Epoch 4/5
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9299 - accuracy: 0.6870 - val_loss: 1.9146 - val_accuracy: 0.7825
# Epoch 5/5
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9005 - accuracy: 0.7155 - val_loss: 1.8877 - val_accuracy: 0.8250
# 13/13 [==============================] - 0s 3ms/step
# Epoch 1/5
# 63/63 [==============================] - 1s 11ms/step - loss: 2.0250 - accuracy: 0.5380 - val_loss: 2.0026 - val_accuracy: 0.7100
# Epoch 2/5
# 63/63 [==============================] - 0s 7ms/step - loss: 1.9899 - accuracy: 0.6090 - val_loss: 1.9691 - val_accuracy: 0.7650
# Epoch 3/5
# 63/63 [==============================] - 0s 7ms/step - loss: 1.9531 - accuracy: 0.6725 - val_loss: 1.9352 - val_accuracy: 0.7725
# Epoch 4/5
# 63/63 [==============================] - 0s 8ms/step - loss: 1.9135 - accuracy: 0.7195 - val_loss: 1.9091 - val_accuracy: 0.7625
# Epoch 5/5
# 63/63 [==============================] - 0s 8ms/step - loss: 1.8808 - accuracy: 0.7325 - val_loss: 1.8775 - val_accuracy: 0.7650
# 13/13 [==============================] - 0s 3ms/step
# 0.7325

# %%
average_accuracy = 0
for i in range(5):
  transfer = TransferClassifier(name = "VGG19")
  transfer.fit(train_data, train_labels, epochs = 8, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
  predictions = (transfer.predict(field_data) > 0.5)
  accuracy = accuracy_score(field_labels, predictions)
  print('Accuracy:%0.2f'%accuracy)
  average_accuracy += accuracy

average_accuracy  /= 5.0
print(average_accuracy)
# Out:
# Epoch 1/8
# 63/63 [==============================] - 7s 70ms/step - loss: 0.6950 - accuracy: 0.5875 - val_loss: 0.5108 - val_accuracy: 0.8250
# Epoch 2/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.4519 - accuracy: 0.7965 - val_loss: 0.5613 - val_accuracy: 0.7150
# Epoch 3/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.2754 - accuracy: 0.8975 - val_loss: 0.6044 - val_accuracy: 0.7400
# Epoch 4/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1999 - accuracy: 0.9285 - val_loss: 0.5152 - val_accuracy: 0.7975
# Epoch 5/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1617 - accuracy: 0.9470 - val_loss: 0.5738 - val_accuracy: 0.7925
# Epoch 6/8
# 63/63 [==============================] - 4s 68ms/step - loss: 0.1616 - accuracy: 0.9390 - val_loss: 0.5844 - val_accuracy: 0.8125
# Epoch 7/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1342 - accuracy: 0.9565 - val_loss: 0.9857 - val_accuracy: 0.6975
# Epoch 8/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1046 - accuracy: 0.9650 - val_loss: 1.0860 - val_accuracy: 0.6900
# 13/13 [==============================] - 0s 20ms/step
# Accuracy:0.67
# Epoch 1/8
# 63/63 [==============================] - 7s 69ms/step - loss: 0.7152 - accuracy: 0.5705 - val_loss: 0.5673 - val_accuracy: 0.8200
# Epoch 2/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.4823 - accuracy: 0.7665 - val_loss: 0.4145 - val_accuracy: 0.8175
# Epoch 3/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.2895 - accuracy: 0.8830 - val_loss: 0.6998 - val_accuracy: 0.7150
# Epoch 4/8
# 63/63 [==============================] - 4s 65ms/step - loss: 0.2242 - accuracy: 0.9130 - val_loss: 0.4246 - val_accuracy: 0.8500
# Epoch 5/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.2050 - accuracy: 0.9295 - val_loss: 0.6225 - val_accuracy: 0.7650
# Epoch 6/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1558 - accuracy: 0.9490 - val_loss: 0.5739 - val_accuracy: 0.8100
# Epoch 7/8
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1680 - accuracy: 0.9385 - val_loss: 0.3773 - val_accuracy: 0.8525
# Epoch 8/8
# 63/63 [==============================] - 4s 65ms/step - loss: 0.1298 - accuracy: 0.9570 - val_loss: 0.6328 - val_accuracy: 0.8000
# 13/13 [==============================] - 0s 22ms/step
# Accuracy:0.79
# Epoch 1/8
# 63/63 [==============================] - 7s 71ms/step - loss: 0.7148 - accuracy: 0.5660 - val_loss: 0.5202 - val_accuracy: 0.8600
# Epoch 2/8
# 63/63 [==============================] - 4s 67ms/step - loss: 0.4323 - accuracy: 0.8135 - val_loss: 0.3414 - val_accuracy: 0.8675
# Epoch 3/8
# 63/63 [==============================] - 4s 65ms/step - loss: 0.2639 - accuracy: 0.8935 - val_loss: 0.6338 - val_accuracy: 0.7475
# Epoch 4/8
# 63/63 [==============================] - 4s 65ms/step - loss: 0.2669 - accuracy: 0.8995 - val_loss: 0.4703 - val_accuracy: 0.7900
# Epoch 5/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.2347 - accuracy: 0.9210 - val_loss: 0.6055 - val_accuracy: 0.7675
# Epoch 6/8
# 63/63 [==============================] - 4s 65ms/step - loss: 0.1851 - accuracy: 0.9325 - val_loss: 0.4471 - val_accuracy: 0.8300
# Epoch 7/8
# 63/63 [==============================] - 4s 65ms/step - loss: 0.1559 - accuracy: 0.9430 - val_loss: 0.4737 - val_accuracy: 0.8275
# Epoch 8/8
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1448 - accuracy: 0.9550 - val_loss: 1.0622 - val_accuracy: 0.6800
# 13/13 [==============================] - 0s 24ms/step
# Accuracy:0.66
# Epoch 1/8
# 63/63 [==============================] - 8s 71ms/step - loss: 0.7232 - accuracy: 0.5695 - val_loss: 0.5249 - val_accuracy: 0.8075
# Epoch 2/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.4377 - accuracy: 0.7975 - val_loss: 0.3538 - val_accuracy: 0.8575
# Epoch 3/8
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2698 - accuracy: 0.8970 - val_loss: 0.5991 - val_accuracy: 0.7375
# Epoch 4/8
# 63/63 [==============================] - 4s 64ms/step - loss: 0.1992 - accuracy: 0.9320 - val_loss: 0.7208 - val_accuracy: 0.7350
# Epoch 5/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1497 - accuracy: 0.9515 - val_loss: 1.5559 - val_accuracy: 0.6000
# Epoch 6/8
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1894 - accuracy: 0.9310 - val_loss: 0.6963 - val_accuracy: 0.7475
# Epoch 7/8
# 63/63 [==============================] - 4s 64ms/step - loss: 0.1601 - accuracy: 0.9430 - val_loss: 1.1884 - val_accuracy: 0.6550
# Epoch 8/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1327 - accuracy: 0.9565 - val_loss: 0.8180 - val_accuracy: 0.7375
# 13/13 [==============================] - 0s 21ms/step
# Accuracy:0.74
# Epoch 1/8
# 63/63 [==============================] - 7s 71ms/step - loss: 0.6988 - accuracy: 0.5915 - val_loss: 0.5277 - val_accuracy: 0.8350
# Epoch 2/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.4310 - accuracy: 0.8145 - val_loss: 0.3401 - val_accuracy: 0.8750
# Epoch 3/8
# 63/63 [==============================] - 4s 64ms/step - loss: 0.2527 - accuracy: 0.9110 - val_loss: 0.3174 - val_accuracy: 0.8775
# Epoch 4/8
# 63/63 [==============================] - 4s 68ms/step - loss: 0.2066 - accuracy: 0.9345 - val_loss: 0.8276 - val_accuracy: 0.6950
# Epoch 5/8
# 63/63 [==============================] - 4s 65ms/step - loss: 0.1443 - accuracy: 0.9505 - val_loss: 0.6051 - val_accuracy: 0.8100
# Epoch 6/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1584 - accuracy: 0.9515 - val_loss: 0.8905 - val_accuracy: 0.6925
# Epoch 7/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1305 - accuracy: 0.9600 - val_loss: 1.1811 - val_accuracy: 0.6625
# Epoch 8/8
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1207 - accuracy: 0.9605 - val_loss: 0.9123 - val_accuracy: 0.7075
# 13/13 [==============================] - 0s 16ms/step
# Accuracy:0.72
# 0.7154999999999999

# %%
for i in range (5):
  plot_one_image(train_data, test_labels, i)
print("field_data")
for i in range (5):
  plot_one_image(field_data, field_labels, i)

### END CODE
# Out:
# Label: 1.0
# Label: 1.0
# Label: 0.0
# Label: 0.0
# Label: 0.0
# field_data
# Label: 1.0
# Label: 1.0
# Label: 0.0
# Label: 0.0
# Label: 0.0

# %%
image = train_data[0]
plot_one_image(image)
new_image = rotate(image, rotate = 40)
plot_one_image(new_image)
# Out:
# Label:
# Label:

# %%
image = train_data[0]
plot_one_image(image)
new_image = remove_color(train_data, channel = 0)
plot_one_image(new_image)
# Out:
# Label:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e10bfdcddea9> in <cell line: 4>()
#       2 plot_one_image(image)
#       3 new_image = remove_color(train_data, channel = 0)
# ----> 4 plot_one_image(new_image)
#
# <ipython-input-1-66d94daf5c08> in <lambda>(data, labels, index)
#     283
#     284 # plotting
# --> 285 plot_one_image = lambda data, labels = [], index = None: helpers.plot_one_image(data = data, labels = labels, index = index, image_shape = image_shape);
#     286 plot_acc       = lambda history: helpers.plot_acc(history)
#     287
#
# <ipython-input-1-66d94daf5c08> in plot_one_image(data, labels, index, image_shape)
#     141     if num_dims == 4:
#     142       image = data[index, :]
# --> 143       label = labels[index]
#     144
#     145     # plot image of interest
#
# TypeError: list indices must be integers or slices, not NoneType

# %%
### YOUR CODE HERE

### END CODE

# %%
train_data_rotated_10 = rotate(train_data, rotate=10)

# %%
train_data_rotated_10 = rotate(train_data, rotate=10)

train_data_rotated_180 = rotate(train_data, rotate=180)
train_data_rotated_270 = rotate(train_data, rotate=270)
red_train  = remove_color(remove_color(train_data, channel = 1), channel = 2)

# %%
all_data, all_labels = combine_data([train_data, train_data_rotated_10, train_data_rotated_180, train_data_rotated_270, red_train], \
                                    [train_labels, train_labels, train_labels, train_labels, train_labels,])

### END CODE

# %%
train_data, train_labels = get_train_data()
test_data, test_labels   = get_test_data()
field_data, field_labels   = get_field_data()

average_accuracy = 0.0

for i in range(5):
  cnn = CNNClassifier(2)
  cnn.fit(all_data, all_labels, epochs = 7, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
  predictions = (cnn.predict(field_data) > 0.5)
  accuracy = accuracy_score(field_labels, predictions)
  print('Accuracy:%0.2f'%accuracy)
  average_accuracy += accuracy

average_accuracy  /= 5.0
print(average_accuracy)



### END CODE
# Out:
# Epoch 1/7
# 313/313 [==============================] - 4s 8ms/step - loss: 1.9809 - accuracy: 0.5481 - val_loss: 1.9262 - val_accuracy: 0.8075
# Epoch 2/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.8806 - accuracy: 0.6155 - val_loss: 1.8179 - val_accuracy: 0.8450
# Epoch 3/7
# 313/313 [==============================] - 2s 8ms/step - loss: 1.7850 - accuracy: 0.6866 - val_loss: 1.7096 - val_accuracy: 0.8500
# Epoch 4/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.6857 - accuracy: 0.7418 - val_loss: 1.6087 - val_accuracy: 0.8650
# Epoch 5/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.5832 - accuracy: 0.7908 - val_loss: 1.5039 - val_accuracy: 0.8625
# Epoch 6/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4906 - accuracy: 0.8121 - val_loss: 1.4077 - val_accuracy: 0.8675
# Epoch 7/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4113 - accuracy: 0.8333 - val_loss: 1.3430 - val_accuracy: 0.8525
# 13/13 [==============================] - 0s 2ms/step
# Accuracy:0.81
# Epoch 1/7
# 313/313 [==============================] - 3s 8ms/step - loss: 1.9825 - accuracy: 0.5491 - val_loss: 1.9238 - val_accuracy: 0.8050
# Epoch 2/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.8844 - accuracy: 0.6472 - val_loss: 1.8107 - val_accuracy: 0.7475
# Epoch 3/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.7844 - accuracy: 0.7108 - val_loss: 1.6917 - val_accuracy: 0.8425
# Epoch 4/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.6823 - accuracy: 0.7618 - val_loss: 1.5862 - val_accuracy: 0.8450
# Epoch 5/7
# 313/313 [==============================] - 2s 8ms/step - loss: 1.5856 - accuracy: 0.7955 - val_loss: 1.4883 - val_accuracy: 0.8500
# Epoch 6/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4940 - accuracy: 0.8253 - val_loss: 1.4188 - val_accuracy: 0.8500
# Epoch 7/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4190 - accuracy: 0.8402 - val_loss: 1.3430 - val_accuracy: 0.8500
# 13/13 [==============================] - 0s 2ms/step
# Accuracy:0.81
# Epoch 1/7
# 313/313 [==============================] - 4s 8ms/step - loss: 1.9791 - accuracy: 0.5629 - val_loss: 1.9150 - val_accuracy: 0.6600
# Epoch 2/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.8767 - accuracy: 0.6795 - val_loss: 1.7991 - val_accuracy: 0.8525
# Epoch 3/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.7741 - accuracy: 0.7471 - val_loss: 1.6858 - val_accuracy: 0.8575
# Epoch 4/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.6741 - accuracy: 0.7817 - val_loss: 1.5809 - val_accuracy: 0.8675
# Epoch 5/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.5789 - accuracy: 0.8152 - val_loss: 1.4858 - val_accuracy: 0.8650
# Epoch 6/7
# 313/313 [==============================] - 2s 8ms/step - loss: 1.4959 - accuracy: 0.8321 - val_loss: 1.4077 - val_accuracy: 0.8675
# Epoch 7/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4212 - accuracy: 0.8511 - val_loss: 1.3471 - val_accuracy: 0.8650
# 13/13 [==============================] - 0s 2ms/step
# Accuracy:0.82
# Epoch 1/7
# 313/313 [==============================] - 3s 8ms/step - loss: 1.9818 - accuracy: 0.5638 - val_loss: 1.9134 - val_accuracy: 0.8475
# Epoch 2/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.8805 - accuracy: 0.6563 - val_loss: 1.7898 - val_accuracy: 0.8525
# Epoch 3/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.7781 - accuracy: 0.7297 - val_loss: 1.6764 - val_accuracy: 0.8650
# Epoch 4/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.6795 - accuracy: 0.7616 - val_loss: 1.5799 - val_accuracy: 0.8375
# Epoch 5/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.5911 - accuracy: 0.7978 - val_loss: 1.4761 - val_accuracy: 0.8600
# Epoch 6/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4990 - accuracy: 0.8215 - val_loss: 1.3959 - val_accuracy: 0.8575
# Epoch 7/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4244 - accuracy: 0.8328 - val_loss: 1.3481 - val_accuracy: 0.8400
# 13/13 [==============================] - 0s 2ms/step
# Accuracy:0.80
# Epoch 1/7
# 313/313 [==============================] - 4s 9ms/step - loss: 1.9660 - accuracy: 0.5530 - val_loss: 1.9066 - val_accuracy: 0.5575
# Epoch 2/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.8671 - accuracy: 0.6530 - val_loss: 1.7955 - val_accuracy: 0.8175
# Epoch 3/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.7612 - accuracy: 0.7314 - val_loss: 1.6736 - val_accuracy: 0.8500
# Epoch 4/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.6582 - accuracy: 0.7786 - val_loss: 1.5628 - val_accuracy: 0.8550
# Epoch 5/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.5598 - accuracy: 0.8086 - val_loss: 1.4624 - val_accuracy: 0.8650
# Epoch 6/7
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4756 - accuracy: 0.8311 - val_loss: 1.3793 - val_accuracy: 0.8625
# Epoch 7/7
# 313/313 [==============================] - 2s 8ms/step - loss: 1.3941 - accuracy: 0.8458 - val_loss: 1.3388 - val_accuracy: 0.8300
# 13/13 [==============================] - 0s 2ms/step
# Accuracy:0.80
# 0.8074999999999999

# %%
train_data, train_labels = get_train_data()
test_data, test_labels   = get_test_data()
field_data, field_labels   = get_field_data()

average_accuracy = 0.0

for i in range(5):
  transfer = TransferClassifier(name = 'VGG16')
  transfer.fit(all_data, all_labels, epochs = 8, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
  predictions = (transfer.predict(field_data) > 0.5)
  accuracy = accuracy_score(field_labels, predictions)
  print('Accuracy:%0.2f'%accuracy)
  average_accuracy += accuracy

average_accuracy  /= 5.0
print(average_accuracy)
# Out:
# Epoch 1/8
# 313/313 [==============================] - 20s 53ms/step - loss: 0.5147 - accuracy: 0.7278 - val_loss: 0.3017 - val_accuracy: 0.8750
# Epoch 2/8
# 313/313 [==============================] - 17s 53ms/step - loss: 0.2343 - accuracy: 0.9200 - val_loss: 0.3123 - val_accuracy: 0.8800
# Epoch 3/8
# 313/313 [==============================] - 17s 53ms/step - loss: 0.1786 - accuracy: 0.9384 - val_loss: 0.3266 - val_accuracy: 0.8750
# Epoch 4/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1478 - accuracy: 0.9475 - val_loss: 1.1911 - val_accuracy: 0.6725
# Epoch 5/8
# 313/313 [==============================] - 16s 51ms/step - loss: 0.1179 - accuracy: 0.9629 - val_loss: 0.7230 - val_accuracy: 0.7850
# Epoch 6/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1046 - accuracy: 0.9644 - val_loss: 0.6294 - val_accuracy: 0.8150
# Epoch 7/8
# 313/313 [==============================] - 17s 53ms/step - loss: 0.0939 - accuracy: 0.9691 - val_loss: 1.7237 - val_accuracy: 0.6300
# Epoch 8/8
# 313/313 [==============================] - 16s 53ms/step - loss: 0.0878 - accuracy: 0.9719 - val_loss: 1.0582 - val_accuracy: 0.7425
# 13/13 [==============================] - 0s 18ms/step
# Accuracy:0.71
# Epoch 1/8
# 313/313 [==============================] - 19s 53ms/step - loss: 0.4708 - accuracy: 0.7587 - val_loss: 0.3421 - val_accuracy: 0.8650
# Epoch 2/8
# 313/313 [==============================] - 17s 53ms/step - loss: 0.2389 - accuracy: 0.9152 - val_loss: 0.5235 - val_accuracy: 0.8375
# Epoch 3/8
# 313/313 [==============================] - 16s 53ms/step - loss: 0.1726 - accuracy: 0.9421 - val_loss: 1.0412 - val_accuracy: 0.6700
# Epoch 4/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1438 - accuracy: 0.9537 - val_loss: 0.8042 - val_accuracy: 0.7625
# Epoch 5/8
# 313/313 [==============================] - 16s 51ms/step - loss: 0.1284 - accuracy: 0.9545 - val_loss: 0.5918 - val_accuracy: 0.8250
# Epoch 6/8
# 313/313 [==============================] - 16s 53ms/step - loss: 0.1084 - accuracy: 0.9627 - val_loss: 0.5274 - val_accuracy: 0.8675
# Epoch 7/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1038 - accuracy: 0.9637 - val_loss: 1.1177 - val_accuracy: 0.7200
# Epoch 8/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.0877 - accuracy: 0.9680 - val_loss: 0.8370 - val_accuracy: 0.7900
# 13/13 [==============================] - 0s 18ms/step
# Accuracy:0.78
# Epoch 1/8
# 313/313 [==============================] - 19s 52ms/step - loss: 0.5041 - accuracy: 0.7447 - val_loss: 1.1183 - val_accuracy: 0.6525
# Epoch 2/8
# 313/313 [==============================] - 17s 53ms/step - loss: 0.2755 - accuracy: 0.8953 - val_loss: 0.4991 - val_accuracy: 0.8450
# Epoch 3/8
# 313/313 [==============================] - 17s 53ms/step - loss: 0.1893 - accuracy: 0.9349 - val_loss: 0.6948 - val_accuracy: 0.7950
# Epoch 4/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1603 - accuracy: 0.9461 - val_loss: 0.6530 - val_accuracy: 0.8100
# Epoch 5/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1399 - accuracy: 0.9551 - val_loss: 0.7909 - val_accuracy: 0.7750
# Epoch 6/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1175 - accuracy: 0.9626 - val_loss: 0.7977 - val_accuracy: 0.7875
# Epoch 7/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1003 - accuracy: 0.9662 - val_loss: 1.4367 - val_accuracy: 0.6500
# Epoch 8/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.0931 - accuracy: 0.9690 - val_loss: 0.9741 - val_accuracy: 0.7550
# 13/13 [==============================] - 0s 17ms/step
# Accuracy:0.70
# Epoch 1/8
# 313/313 [==============================] - 19s 53ms/step - loss: 0.5431 - accuracy: 0.7183 - val_loss: 0.6714 - val_accuracy: 0.7250
# Epoch 2/8
# 313/313 [==============================] - 17s 54ms/step - loss: 0.2601 - accuracy: 0.9036 - val_loss: 0.2900 - val_accuracy: 0.8875
# Epoch 3/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.2104 - accuracy: 0.9249 - val_loss: 0.9623 - val_accuracy: 0.7000
# Epoch 4/8
# 313/313 [==============================] - 16s 51ms/step - loss: 0.1636 - accuracy: 0.9464 - val_loss: 0.4676 - val_accuracy: 0.8600
# Epoch 5/8
# 313/313 [==============================] - 16s 51ms/step - loss: 0.1271 - accuracy: 0.9579 - val_loss: 0.7595 - val_accuracy: 0.7850
# Epoch 6/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1142 - accuracy: 0.9626 - val_loss: 0.9790 - val_accuracy: 0.7600
# Epoch 7/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.0990 - accuracy: 0.9664 - val_loss: 0.8630 - val_accuracy: 0.7825
# Epoch 8/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1002 - accuracy: 0.9669 - val_loss: 0.7537 - val_accuracy: 0.7900
# 13/13 [==============================] - 0s 13ms/step
# Accuracy:0.69
# Epoch 1/8
# 313/313 [==============================] - 19s 53ms/step - loss: 0.5515 - accuracy: 0.7071 - val_loss: 0.4335 - val_accuracy: 0.8050
# Epoch 2/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.2734 - accuracy: 0.8990 - val_loss: 0.3903 - val_accuracy: 0.8650
# Epoch 3/8
# 313/313 [==============================] - 22s 69ms/step - loss: 0.2121 - accuracy: 0.9289 - val_loss: 0.2714 - val_accuracy: 0.8925
# Epoch 4/8
# 313/313 [==============================] - 16s 51ms/step - loss: 0.1641 - accuracy: 0.9447 - val_loss: 0.6505 - val_accuracy: 0.7875
# Epoch 5/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1372 - accuracy: 0.9534 - val_loss: 0.5647 - val_accuracy: 0.8100
# Epoch 6/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1280 - accuracy: 0.9589 - val_loss: 0.9648 - val_accuracy: 0.7300
# Epoch 7/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.1098 - accuracy: 0.9642 - val_loss: 0.4863 - val_accuracy: 0.8675
# Epoch 8/8
# 313/313 [==============================] - 16s 52ms/step - loss: 0.0970 - accuracy: 0.9692 - val_loss: 1.1557 - val_accuracy: 0.6775
# 13/13 [==============================] - 0s 17ms/step
# Accuracy:0.65
# 0.7064999999999999

# %% [markdown]
# ## Instructor-Led Discussion: Why does data augmentation improve average performance?

# %% [markdown]
# ![](https://storage.googleapis.com/kaggle-competitions/kaggle/10338/logos/header.png)

# %% [markdown]
# ##Congratulations on completing your model!
#
# By augmenting your data, you've (hopefully) gotten your models working better, even on messy field data!
#
# As a further challenge, you can return to any point in the challenge and try to improve:
# - Try looking at the CNN code in the hidden cell at the top. Can you change the parameters to reduce overfitting?
# - Try out different classifiers from Scikit-learn with augmented data.
# - Create new combinations of augmentations for your data.
# - Whatever ideas you come up with!
